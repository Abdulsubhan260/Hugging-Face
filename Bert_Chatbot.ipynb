# %%
# makinga chatbot by using bert and hugging face

# step 1 preparing our data for chatbot


# !pip install evaluate
import pandas as pd


from datasets import Dataset

data={
  "intents": [
    {
      "tag": "greeting",
      "patterns": [
        "Hi",
        "Hello",
        "Hey",
        "Assalamualaikum",
        "What's up?",
        "Good morning",
        "Good evening",
        "helo",
        "hy",
        "aoa",
        "Greetings",
        "Howdy",
        "Hi there",
        "Hello there",
        "Hey there",
        "Good afternoon",
        "Salaam",
        "Yo",
        "Hiya",
        "What is going on?",
        "How do you do?",
        "Nice to meet you",
        "Pleased to meet you",
        "Good day",
        "Morning",
        "Evening",
        "Afternoon"
      ],
      "responses": [
        "Hello! How can I help you today?",
        "Walaikum Assalam! I am here to help.",
        "Hi there! Nice to see you.",
        "Hello! What is on your mind?"
      ]
    },
    {
      "tag": "goodbye",
      "patterns": [
        "Bye",
        "See you",
        "Goodbye",
        "Khuda hafiz",
        "Allah Hafiz",
        "Leaving now",
        "tc",
        "tata",
        "See you later",
        "Catch you later",
        "I am going now",
        "Gotta go",
        "Talk to you later",
        "Until next time",
        "Farewell",
        "Take care",
        "I have to leave",
        "Time to go",
        "Bye bye",
        "Later",
        "Peace out",
        "I am leaving",
        "Got to run",
        "See ya",
        "Signing off"
      ],
      "responses": [
        "Goodbye! Have a nice day 😊",
        "Khuda hafiz! Take care.",
        "See you soon!",
        "Allah Hafiz!"
      ]
    },
    {
      "tag": "thanks",
      "patterns": [
        "Thanks",
        "Thank you",
        "Shukriya",
        "You are helpful",
        "Nice work",
        "ok thanks",
        "ok thank you",
        "Thanks a lot",
        "Thank you so much",
        "I appreciate it",
        "Much appreciated",
        "That was helpful",
        "Great job",
        "You helped me a lot",
        "Thanks for your help",
        "I am grateful",
        "Excellent work",
        "Well done",
        "Perfect",
        "Amazing",
        "You are great",
        "Awesome",
        "That is exactly what I needed",
        "You are the best",
        "Thank you very much"
      ],
      "responses": [
        "You're welcome!",
        "Happy to help!",
        "Koi masla nahi!",
        "My pleasure!"
      ]
    },
    {
      "tag": "bot_identity",
      "patterns": [
        "Who are you",
        "What is your name",
        "your name?",
        "Introduction",
        "Who created you",
        "name",
        "Tell me about yourself",
        "What should I call you",
        "Can you introduce yourself",
        "What are you",
        "Are you a bot",
        "Are you human",
        "What do you do",
        "Who built you",
        "What is your purpose",
        "Tell me your name",
        "May I know your name",
        "What are you called",
        "Who made you",
        "Are you AI",
        "Bot name",
        "Are you a robot",
        "Your identity"
      ],
      "responses": [
        "I am Sam, your friendly AI Assistant.",
        "My name is Sam! I live in your computer.",
        "I am a Chatbot built with Python and PyTorch."
      ]
    },
    {
      "tag": "how_are_you",
      "patterns": [
        "How are you doing",
        "How are you",
        "Are you fine",
        "Kaise ho",
        "What is up",
        "How is it going",
        "Are you okay",
        "How do you feel",
        "Are you good",
        "How are things",
        "How have you been",
        "Are you alright",
        "How is everything",
        "All good?",
        "You doing okay",
        "How is your day",
        "You fine?",
        "How are you feeling",
        "Everything okay",
        "What is your status",
        "Are you well"
      ],
      "responses": [
        "I am just a computer program, but I function perfectly!",
        "Alhamdulillah, I am doing great! Thanks for asking.",
        "I am fully charged and ready to chat!"
      ]
    },
    {
      "tag": "weather_query",
      "patterns": [
        "How is the weather",
        "Is it raining",
        "What is the temperature",
        "Is it hot today",
        "Weather update",
        "weather",
        "Will it rain today",
        "Is it sunny",
        "What is the forecast",
        "Is it cold outside",
        "Check the weather",
        "Tell me the weather",
        "Is it cloudy?",
        "Temperature now",
        "Is it warm",
        "Weather conditions",
        "Current weather",
        "Is it nice outside",
        "What is it like outside",
        "Should I bring an umbrella",
        "Climate today",
        "Is it stormy",
        "Weather report"
      ],
      "responses": [
        "I cannot look outside the window, but I hope it is sunny!",
        "You should check Google Weather for real-time updates.",
        "It's always cool inside the server room! ❄️"
      ]
    },
    {
      "tag": "pakistan_general_knowledge",
      "patterns": [
        "Tell me about Pakistan",
        "What is Pakistan",
        "Where is Pakistan",
        "Pak information",
        "tell me about paksitan",
        "paksitan",
        "Describe Pakistan",
        "Pakistan location",
        "Which country is Pakistan",
        "Give me info on Pakistan",
        "What do you know about Pakistan",
        "Pakistan facts",
        "Tell me Pakistan details",
        "Where is Pak located?",
        "Information about Pakistan",
        "Can you tell me about Pakistan?",
        "What is special about Pakistan?",
        "Pakistan geography",
        "Pak country info",
        "About Pakistan",
        "Pakistan overview",
        "Explain Pakistan",
        "Pakistan country?"
      ],
      "responses": [
        "Pakistan is a beautiful country in South Asia, home to K2 and huge mountains.",
        "Pakistan is known for its hospitality, cricket, and delicious food.",
        "It is the land of the pure, founded in 1947."
      ]
    },
    {
      "tag": "pakistan_capital",
      "patterns": [
        "What is the capital of Pakistan?",
        "Capital city",
        "Is Karachi the capital?",
        "Islamabad",
        "Pakistan capital?",
        "Which city is the capital?",
        "Name the capital of Pakistan",
        "Capital city of Pak?",
        "Tell me the capital",
        "What is Pak capital?",
        "Where is the capital?",
        "Is Islamabad the capital?",
        "Pakistan main city?",
        "Capital of Pakistan please",
        "Can you tell me the capital of Pakistan?",
        "Which is Pakistan's capital?",
        "Pak capital city name?",
        "Capital?",
        "Main city Pakistan?",
        "Government city Pakistan?",
        "Administrative capital?"
      ],
      "responses": [
        "The capital of Pakistan is Islamabad.",
        "It used to be Karachi, but now it is the beautiful city of Islamabad."
      ]
    },
    {
      "tag": "independence_day",
      "patterns": [
        "When is independence day?",
        "Birthday of Pakistan",
        "14 August",
        "Freedom day",
        "Pakistan independence?",
        "When did Pakistan get freedom?",
        "Independence date?",
        "Azadi day?",
        "When was Pakistan created?",
        "Pakistan founding date?",
        "What is the independence day of Pakistan?",
        "14th August significance?",
        "Jashn e Azadi?",
        "Pakistan creation date?",
        "Freedom date Pakistan?",
        "When did Pakistan become independent?",
        "Pakistan birth date?",
        "National day Pakistan?",
        "Pakistan freedom?",
        "Independence celebration?",
        "Pak azadi?",
        "14 august kya hai?"
      ],
      "responses": [
        "Pakistan celebrates Independence Day on 14th August 1947.",
        "14th August! The day of freedom.",
        "Jashn-e-Azadi is on the 14th of August 🇵🇰."
      ]
    },
    {
      "tag": "national_animal",
      "patterns": [
        "What is the national animal?",
        "Pakistan national animal",
        "Markhor",
        "Animal symbol",
        "National animal of Pakistan?",
        "Which animal represents Pakistan?",
        "Pak national animal?",
        "Tell me the national animal",
        "What animal is on Pakistan emblem?",
        "National animal name?",
        "Pakistan animal symbol?",
        "Official animal Pakistan?",
        "Is Markhor national animal?",
        "What is Pak national animal?",
        "Animal of Pakistan?",
        "National wildlife Pakistan?",
        "Pakistan's animal?",
        "Which is the national animal of Pakistan?",
        "Symbolic animal Pakistan?",
        "Markhor Pakistan?",
        "National animal please?"
      ],
      "responses": [
        "The national animal of Pakistan is the Markhor (a large wild goat). 🐐"
      ]
    },
    {
      "tag": "national_bird",
      "patterns": [
        "What is the national bird?",
        "Pakistan bird",
        "Chukar",
        "National bird of Pakistan?",
        "Which bird represents Pakistan?",
        "Pak national bird?",
        "Tell me the national bird",
        "Bird symbol Pakistan?",
        "What is Pak national bird?",
        "Official bird Pakistan?",
        "Is Chukar national bird?",
        "Chakoor?",
        "Pakistan's bird?",
        "National bird name?",
        "Which is the national bird of Pakistan?",
        "Bird of Pakistan?",
        "Symbolic bird Pakistan?",
        "Chukar partridge?",
        "National bird please?",
        "Pakistan bird symbol?",
        "What bird is national?"
      ],
      "responses": [
        "The national bird is the Chukar Partridge (Chakoor). 🐦"
      ]
    },
    {
      "tag": "national_flower",
      "patterns": [
        "What is the national flower?",
        "Pakistan national flower",
        "Jasmine",
        "Chambeli",
        "National flower of Pakistan?",
        "Which flower represents Pakistan?",
        "Pak national flower?",
        "Tell me the national flower",
        "Flower symbol Pakistan?",
        "What is Pak national flower?",
        "Official flower Pakistan?",
        "Is Jasmine national flower?",
        "Pakistan's flower?",
        "National flower name?",
        "Which is the national flower of Pakistan?",
        "Flower of Pakistan?",
        "Symbolic flower Pakistan?",
        "Chambeli Pakistan?",
        "National flower please?",
        "Pakistan flower symbol?",
        "What flower is national?"
      ],
      "responses": [
        "The national flower of Pakistan is Jasmine (Chambeli). 🌸"
      ]
    },
    {
      "tag": "national_sport",
      "patterns": [
        "What is the national sport?",
        "Pakistan national game",
        "Is cricket national sport?",
        "Hockey",
        "National sport of Pakistan?",
        "Which sport represents Pakistan?",
        "Pak national sport?",
        "Tell me the national sport",
        "Game symbol Pakistan?",
        "What is Pak national sport?",
        "Official sport Pakistan?",
        "Is Hockey national sport?",
        "Pakistan's sport?",
        "National sport name?",
        "Which is the national sport of Pakistan?",
        "Sport of Pakistan?",
        "Field hockey Pakistan?",
        "National game please?",
        "Pakistan sport symbol?",
        "What sport is national?",
        "Is cricket the national game?"
      ],
      "responses": [
        "The national sport is Field Hockey, even though cricket is more famous! 🏑"
      ]
    },
    {
      "tag": "cricket_definition",
      "patterns": [
        "what is cricket",
        "explain cricket",
        "cricket game",
        "Define cricket",
        "Tell me about cricket",
        "Cricket sport?",
        "What does cricket mean?",
        "How is cricket played?",
        "Cricket rules?",
        "Describe cricket",
        "Cricket explanation?",
        "What is cricket sport?",
        "Cricket game explain",
        "Can you explain cricket?",
        "What is the cricket game?",
        "Cricket definition?",
        "Tell me cricket rules",
        "How does cricket work?",
        "Cricket info?",
        "About cricket?",
        "Cricket meaning?"
      ],
      "responses": [
        "Cricket is a game played with a bat and ball between two teams.",
        "It is a sport with 11 players per side."
      ]
    },
    {
      "tag": "babar_azam",
      "patterns": [
        "who is king?",
        "who is babar?",
        "babar azam",
        "cover drive",
        "Tell me about Babar",
        "Who is Babar Azam?",
        "Babar Azam info?",
        "King Babar?",
        "Is Babar the captain?",
        "Babar Azam cricketer?",
        "Best batsman Pakistan?",
        "Who is the king of cricket?",
        "Babar stats?",
        "Tell me about King",
        "Babar Azam career?",
        "Pakistan captain name?",
        "Who plays cover drive?",
        "Babar Azam achievements?",
        "Is Babar good?",
        "King of cricket Pakistan?",
        "Babar Azam details?"
      ],
      "responses": [
        "Babar Azam is the King! 👑",
        "The captain of Pakistan and master of the cover drive.",
        "He is currently one of the best batsmen in the world."
      ]
    },
    {
      "tag": "imran_khan",
      "patterns": [
        "who is imran khan?",
        "kaptaan",
        "kaptan",
        "captain",
        "1992 world cup",
        "imran",
        "khan sahb",
        "IK",
        "Tell me about Imran Khan",
        "Who is IK?",
        "Imran Khan info?",
        "Who won 1992 world cup?",
        "Former PM Pakistan?",
        "Is Imran Khan a cricketer?",
        "Kaptaan who?",
        "Imran Khan career?",
        "Who is Khan Sahab?",
        "Pakistan PM name?",
        "1992 captain?",
        "Imran Khan achievements?",
        "Tell me about Kaptaan",
        "Who is the legend?",
        "Imran Khan cricket?",
        "World cup winner?"
      ],
      "responses": [
        "Imran Khan is a legend.",
        "He is the former PM and the 1992 World Cup winning captain."
      ]
    },
    {
      "tag": "funny",
      "patterns": [
        "Tell me a joke",
        "Are you funny?",
        "Make me laugh",
        "Joke",
        "Say something funny",
        "Do you know jokes?",
        "Make me smile",
        "Tell a joke",
        "Funny joke please",
        "Can you make me laugh?",
        "Give me a joke",
        "Something funny?",
        "Joke please",
        "Are you humorous?",
        "Tell me something funny",
        "Crack a joke",
        "Humor me",
        "I need a laugh",
        "Cheer me up",
        "Make a joke",
        "Got any jokes?",
        "Funny?"
      ],
      "responses": [
        "Why did the developer go broke? Because he used up all his cache! ",
        "Why was the robot angry? Someone pushed his buttons!",
        "My battery is getting low... Just kidding! "
      ]
    },
    {
      "tag": "food",
      "patterns": [
        "I am hungry",
        "What should I eat?",
        "Do you like Biryani?",
        "Best food",
        "iam hungry",
        "im hungry",
        "Food recommendation?",
        "What to eat?",
        "Suggest food",
        "I need food",
        "Hungry",
        "Tell me what to eat",
        "Best Pakistani food?",
        "Do you eat?",
        "What is good to eat?",
        "Food suggestions?",
        "I want to eat",
        "What is your favorite food?",
        "Recommend food",
        "What should I have?",
        "Best dish?",
        "Feeling hungry",
        "Food?"
      ],
      "responses": [
        "Biryani is the answer to everything! ",
        "You should definitely have some Biryani.",
        "Robots don't eat, but I hear Chicken Tikka is great."
      ]
    }
  ]
}





text=[]
labels=[]
label2id={}
id2label={}

for i,intent in enumerate(data["intents"]):
  tag=intent['tag']
  label2id[tag]=i
  id2label[i]=tag

  for pattern in intent['patterns']:
    text.append(pattern)
    labels.append(i)


df = pd.DataFrame({'text': text, 'label': labels})
dataset = Dataset.from_pandas(df)


dataset = dataset.train_test_split(test_size=0.2)

print(f"Unique Labels: {label2id}")
print(dataset["train"][0])

# %%
# making a tokenizer

from transformers import AutoTokenizer
model_check_point="bert-base-uncased"

tokenizer=AutoTokenizer.from_pretrained(model_check_point)



def preprocess_function(examples):
  return tokenizer(examples["text"],trunaction=True,padding="max_length",max_length=128)




tokenized_datasets=dataset.map(preprocess_function,batched=True)

# %%
from transformers import AutoModelForSequenceClassification


num_labels = len(label2id)


model = AutoModelForSequenceClassification.from_pretrained(
    model_check_point,
    num_labels=num_labels,
    id2label=id2label,
    label2id=label2id
)

# %%
from transformers import TrainingArguments, Trainer


args = TrainingArguments(
    "bert-chatbot",
    eval_strategy="epoch",
    save_strategy="epoch",
    learning_rate=3e-5,
    per_device_train_batch_size=8,
    num_train_epochs=15,

    logging_steps=10,
    load_best_model_at_end=True
)

import numpy as np
from evaluate import load


metric = load("accuracy")

def compute_metrics(eval_pred):
    logits, labels = eval_pred

    predictions = np.argmax(logits, axis=-1)

    return metric.compute(predictions=predictions, references=labels)


trainer = Trainer(
    model=model,
    args=args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["test"],
    compute_metrics=compute_metrics
)


trainer.train()

# %%
import torch
import random

def get_chat_response(text):



    inputs = tokenizer(text, return_tensors="pt").to(model.device)





    with torch.no_grad():
        logits = model(**inputs).logits


    probs = torch.softmax(logits, dim=1)

    max_prob, predicted_id = torch.max(probs, dim=1)

    confidence = max_prob.item()
    print(f"DEBUG: Confidence for '{text}' is {confidence:.4f}")


    if confidence < 0.65:
        return "I did not understand it properly. Could you say that differently?"


    predicted_id = torch.argmax(logits, dim=1).item()


    predicted_tag = id2label[predicted_id]


    for intent in data["intents"]:
        if intent["tag"] == predicted_tag:
            response = random.choice(intent["responses"])
            return response


print("Bot: I am ready! (Type 'quit' to exit)")
while True:


    user_input = input("You: ")
    if user_input.lower() == "quit":
        break

    response = get_chat_response(user_input)
    print(f"Bot: {response}")
# Out:
# Bot: I am ready! (Type 'quit' to exit)
# You: hi
# DEBUG: Confidence for 'hi' is 0.9815
# Bot: Hello! How can I help you today?
# You: Hello
# DEBUG: Confidence for 'Hello' is 0.9810
# Bot: Hello! How can I help you today?
# You: who are you
# DEBUG: Confidence for 'who are you' is 0.9623
# Bot: I am a Chatbot built with Python and PyTorch.
# You: who created you
# DEBUG: Confidence for 'who created you' is 0.9682
# Bot: My name is Sam! I live in your computer.
# You: how are you
# DEBUG: Confidence for 'how are you' is 0.9712
# Bot: I am just a computer program, but I function perfectly!
# You: what is temprature
# DEBUG: Confidence for 'what is temprature' is 0.4613
# Bot: I did not understand it properly. Could you say that differently?
# You: what is the temprature?
# DEBUG: Confidence for 'what is the temprature?' is 0.4696
# Bot: I did not understand it properly. Could you say that differently?
# You: Is it raining?
# DEBUG: Confidence for 'Is it raining?' is 0.9695
# ...

# %%
trainer.save_model("./final_intent_bot")
tokenizer.save_pretrained("./final_intent_bot")

# %%
import shutil
import os


if os.path.exists("./bert-chatbot"):
    shutil.rmtree("./bert-chatbot")

print("Disk space cleared! Only your final_intent_bot remains.")
